# %%
import pandas as pd  

df = pd.read_csv("/Users/sharath/Documents/BIA/Python/Practice Problems/Pandas Problems/Automobile_data.csv", na_values={
'price':["?","n.a"],
'stroke':["?","n.a"],
'horsepower':["?","n.a"],
'peak-rpm':["?","n.a"],
'average-mileage':["?","n.a"]})

# %%
df.to_csv("/Users/sharath/Documents/BIA/Python/Practice Problems/Pandas Problems/Automobile_data.csv")
